# %%
import pandas as pd
from backend.src.models.feature_provider import FeatureProvider
from backend.src.utils.logging_handler import setup_logging
from backend.src.utils.config import Config

config = Config("../../config.yaml")
setup_logging()

feature_engineering_config = config.get("feature_engineering")
preprocessor_config = config.get("preprocess")
model_config = config.get("model")

target_feature = preprocessor_config.get("target")
trend_length = preprocessor_config.get("trend_length")
window_size = preprocessor_config.get("window_size")
epochs: int = model_config.get("epochs")
batch_size: int = model_config.get("batch_size")

interval: str = feature_engineering_config.get("time_series_interval")

training_file_path: str = f"../data/twelvedata/time series ({interval})/AAPL_time_series.csv"
validation_file_path: str = f"../data/twelvedata/time series ({interval})/ABBV_time_series.csv"

training_df = pd.read_csv(training_file_path)
validation_df = pd.read_csv(validation_file_path)

training_feature_provider = FeatureProvider(training_df)
training_feature_time_series = training_feature_provider.feature_time_series

validation_feature_provider = FeatureProvider(validation_df)
validation_feature_time_series = validation_feature_provider.feature_time_series

# %%
from backend.src.models.stock_trend_lstm.stock_trend_lstm_pipeline import StockTrendLSTMPipeline
import tensorflow as tf
tf.get_logger().setLevel('ERROR')

my_model = StockTrendLSTMPipeline(training_feature_time_series, validation_feature_time_series, target_feature, trend_length, window_size, epochs, batch_size)
history = my_model.history
# Out:
# 2025-12-22 00:39:53,682 | WARNING | tensorflow | From C:\Users\mohae\Desktop\StockTrendPredictor\.venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 2025-12-22 00:40:01,077 | INFO | backend.src.models.stock_trend_lstm.stock_trend_lstm_pipeline | StockTrendLSTMPipeline initiated
# 2025-12-22 00:40:01,127 | INFO | backend.src.models.stock_trend_lstm.time_series_preprocessor | Preprocessing summary | input rows: 4970 | output rows: 4970 | dropped: 0 (100.00% retained)
# 2025-12-22 00:40:01,149 | INFO | backend.src.models.stock_trend_lstm.time_series_preprocessor | Preprocessing summary | input rows: 4970 | output rows: 4970 | dropped: 0 (100.00% retained)
# 2025-12-22 00:40:01,160 | INFO | backend.src.models.stock_trend_lstm.stock_trend_lstm_pipeline | Preprocessing training/validation data completed
# 2025-12-22 00:40:02,637 | INFO | root | Train label mean: 0.5425
# 2025-12-22 00:40:02,637 | INFO | root | Validation label mean: 0.5617
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 50)            13000
#
#  dropout (Dropout)           (None, 30, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 33251 (129.89 KB)
# Trainable params: 33251 (129.89 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 155/155 [==============================] - 10s 32ms/step - loss: 0.6653 - accuracy: 0.6091 - val_loss: 0.6288 - val_accuracy: 0.6599
# Epoch 2/100
# 155/155 [==============================] - 4s 26ms/step - loss: 0.5698 - accuracy: 0.7144 - val_loss: 0.5414 - val_accuracy: 0.7389
# Epoch 3/100
# 155/155 [==============================] - 4s 28ms/step - loss: 0.5033 - accuracy: 0.7648 - val_loss: 0.4835 - val_accuracy: 0.7761
# Epoch 4/100
# 155/155 [==============================] - 4s 25ms/step - loss: 0.4650 - accuracy: 0.7897 - val_loss: 0.4620 - val_accuracy: 0.7840
# Epoch 5/100
# 155/155 [==============================] - 4s 25ms/step - loss: 0.4434 - accuracy: 0.7974 - val_loss: 0.4392 - val_accuracy: 0.7986
# Epoch 6/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.4267 - accuracy: 0.8113 - val_loss: 0.4295 - val_accuracy: 0.8016
# Epoch 7/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.4108 - accuracy: 0.8144 - val_loss: 0.4255 - val_accuracy: 0.7990
# Epoch 8/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.4032 - accuracy: 0.8182 - val_loss: 0.4206 - val_accuracy: 0.8081
# Epoch 9/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3948 - accuracy: 0.8277 - val_loss: 0.4085 - val_accuracy: 0.8115
# Epoch 10/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3902 - accuracy: 0.8267 - val_loss: 0.4285 - val_accuracy: 0.8016
# Epoch 11/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3925 - accuracy: 0.8253 - val_loss: 0.4076 - val_accuracy: 0.8121
# Epoch 12/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3875 - accuracy: 0.8233 - val_loss: 0.4044 - val_accuracy: 0.8148
# Epoch 13/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3785 - accuracy: 0.8356 - val_loss: 0.4177 - val_accuracy: 0.8089
# Epoch 14/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3741 - accuracy: 0.8362 - val_loss: 0.4253 - val_accuracy: 0.8040
# Epoch 15/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3718 - accuracy: 0.8330 - val_loss: 0.3969 - val_accuracy: 0.8168
# Epoch 16/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3693 - accuracy: 0.8377 - val_loss: 0.3972 - val_accuracy: 0.8172
# Epoch 17/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3657 - accuracy: 0.8389 - val_loss: 0.3966 - val_accuracy: 0.8186
# Epoch 18/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3658 - accuracy: 0.8405 - val_loss: 0.3980 - val_accuracy: 0.8215
# Epoch 19/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3602 - accuracy: 0.8372 - val_loss: 0.4092 - val_accuracy: 0.8128
# Epoch 20/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3606 - accuracy: 0.8399 - val_loss: 0.3949 - val_accuracy: 0.8168
# Epoch 21/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3518 - accuracy: 0.8437 - val_loss: 0.3902 - val_accuracy: 0.8192
# Epoch 22/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3518 - accuracy: 0.8399 - val_loss: 0.3944 - val_accuracy: 0.8200
# Epoch 23/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3494 - accuracy: 0.8425 - val_loss: 0.3885 - val_accuracy: 0.8247
# Epoch 24/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3460 - accuracy: 0.8433 - val_loss: 0.3887 - val_accuracy: 0.8194
# Epoch 25/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3472 - accuracy: 0.8472 - val_loss: 0.3882 - val_accuracy: 0.8223
# Epoch 26/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3444 - accuracy: 0.8460 - val_loss: 0.3938 - val_accuracy: 0.8190
# Epoch 27/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3352 - accuracy: 0.8464 - val_loss: 0.3868 - val_accuracy: 0.8239
# Epoch 28/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3361 - accuracy: 0.8500 - val_loss: 0.4031 - val_accuracy: 0.8176
# Epoch 29/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3351 - accuracy: 0.8569 - val_loss: 0.3811 - val_accuracy: 0.8259
# Epoch 30/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3263 - accuracy: 0.8577 - val_loss: 0.3884 - val_accuracy: 0.8233
# Epoch 31/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3267 - accuracy: 0.8534 - val_loss: 0.3804 - val_accuracy: 0.8249
# Epoch 32/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3226 - accuracy: 0.8565 - val_loss: 0.4018 - val_accuracy: 0.8198
# Epoch 33/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3195 - accuracy: 0.8585 - val_loss: 0.3762 - val_accuracy: 0.8314
# Epoch 34/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3156 - accuracy: 0.8654 - val_loss: 0.3875 - val_accuracy: 0.8249
# Epoch 35/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3110 - accuracy: 0.8668 - val_loss: 0.3707 - val_accuracy: 0.8360
# Epoch 36/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.3025 - accuracy: 0.8700 - val_loss: 0.3688 - val_accuracy: 0.8314
# Epoch 37/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.2972 - accuracy: 0.8739 - val_loss: 0.3574 - val_accuracy: 0.8433
# Epoch 38/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.2931 - accuracy: 0.8755 - val_loss: 0.3645 - val_accuracy: 0.8385
# Epoch 39/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.2888 - accuracy: 0.8789 - val_loss: 0.3618 - val_accuracy: 0.8441
# Epoch 40/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.2791 - accuracy: 0.8864 - val_loss: 0.3487 - val_accuracy: 0.8441
# Epoch 41/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.2693 - accuracy: 0.8887 - val_loss: 0.3474 - val_accuracy: 0.8494
# Epoch 42/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.2644 - accuracy: 0.8899 - val_loss: 0.3329 - val_accuracy: 0.8498
# Epoch 43/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.2538 - accuracy: 0.8988 - val_loss: 0.3271 - val_accuracy: 0.8579
# Epoch 44/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.2509 - accuracy: 0.9010 - val_loss: 0.3299 - val_accuracy: 0.8540
# Epoch 45/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.2404 - accuracy: 0.9047 - val_loss: 0.3387 - val_accuracy: 0.8536
# Epoch 46/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.2394 - accuracy: 0.9024 - val_loss: 0.3168 - val_accuracy: 0.8617
# Epoch 47/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.2334 - accuracy: 0.9077 - val_loss: 0.3219 - val_accuracy: 0.8597
# Epoch 48/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.2283 - accuracy: 0.9119 - val_loss: 0.2895 - val_accuracy: 0.8769
# Epoch 49/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.2238 - accuracy: 0.9043 - val_loss: 0.2963 - val_accuracy: 0.8729
# Epoch 50/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.2218 - accuracy: 0.9152 - val_loss: 0.3037 - val_accuracy: 0.8676
# Epoch 51/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.2113 - accuracy: 0.9176 - val_loss: 0.2786 - val_accuracy: 0.8836
# Epoch 52/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.2029 - accuracy: 0.9206 - val_loss: 0.2980 - val_accuracy: 0.8745
# Epoch 53/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.2023 - accuracy: 0.9198 - val_loss: 0.2929 - val_accuracy: 0.8789
# Epoch 54/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.1986 - accuracy: 0.9213 - val_loss: 0.2893 - val_accuracy: 0.8787
# Epoch 55/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.1881 - accuracy: 0.9259 - val_loss: 0.2756 - val_accuracy: 0.8852
# Epoch 56/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.1891 - accuracy: 0.9269 - val_loss: 0.2708 - val_accuracy: 0.8864
# Epoch 57/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.1851 - accuracy: 0.9277 - val_loss: 0.2978 - val_accuracy: 0.8800
# Epoch 58/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.1863 - accuracy: 0.9281 - val_loss: 0.3178 - val_accuracy: 0.8690
# Epoch 59/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.1770 - accuracy: 0.9304 - val_loss: 0.2896 - val_accuracy: 0.8864
# Epoch 60/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.1771 - accuracy: 0.9330 - val_loss: 0.2842 - val_accuracy: 0.8822
# Epoch 61/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.1762 - accuracy: 0.9294 - val_loss: 0.2962 - val_accuracy: 0.8804
# Epoch 62/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.1710 - accuracy: 0.9330 - val_loss: 0.2931 - val_accuracy: 0.8872
# Epoch 63/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.1634 - accuracy: 0.9393 - val_loss: 0.3233 - val_accuracy: 0.8735
# Epoch 64/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.1657 - accuracy: 0.9362 - val_loss: 0.2863 - val_accuracy: 0.8862
# Epoch 65/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.1670 - accuracy: 0.9368 - val_loss: 0.3476 - val_accuracy: 0.8777
# Epoch 66/100
# 155/155 [==============================] - 4s 24ms/step - loss: 0.1582 - accuracy: 0.9389 - val_loss: 0.3047 - val_accuracy: 0.8903
# 2025-12-22 00:44:14,834 | INFO | backend.src.models.stock_trend_lstm.stock_trend_lstm_model | Model saved to:C:/Users/mohae/Desktop/StockTrendPredictor/backend/src/models/saved models/trained_StockTrendLSTM_model.keras

# %%
from backend.src.models.visualizing_service import plot_model_accuracy
plot_model_accuracy(history)
